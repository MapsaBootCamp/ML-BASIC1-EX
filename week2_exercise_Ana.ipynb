# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=6 color=#F32500>
#         <div  align=center>
#             تمرین هفته دوم بوت کمپ یادگیری ماشین-
#             مپصا
#         </div>
#         <br/>
#     </font>
# </div>

# %% [markdown]
# <div style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
# 		<div align=center>
# 			<font face="IranNastaliq" size=5>
#                   چون عهده نمی‌شود کسی فردا را
#                 <br><br>
#                  حالی خوش دار این دل پر سودا را
#                 <br><br>
#                 می نوش به ماهتاب ای ماه که ماه
#                 <br><br>
#                 بسیار بتابد و نیابد ما را
#                 <p></p>
# 			</font>
#         </div>
#     </font>
# </div>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
# 		<font color=red size=5>
#             سوال اول:‌
#         </font>
# در این تمرین قصد داریم به تحلیل داده های فیلم های برتر سینمای جهان به معیار imdb بپردازیم. ابتدا دادههای مربوط به فیلم را از فایل csv فراخوانی میکنیم
#         <br/>
#     </font>
# </div>

# %%
movies = pd.read_csv("imdb_movie_rank.csv")
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.shape
# Out:
# (976, 7)

# %%
movies.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
#         در این دیتاست اگر داده ای وجود دارد که مقدار nullدارد سطرش را حذف کنید.
#         <br/>
#     </font>
# </div>

# %%
#TODO
movies.isna().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
movies.dropna(subset=['content_rating'], inplace=True)
movies.isna().sum()
# Out:
# star_rating       0
# title             0
# content_rating    0
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
#         فیلم ها را براساس مدت زمان فیلم به صورت نزولی مرتب کنید و پنجاه تای اول را در فایل csv با نام long_time ذخیره کنید
#         <br/>
#     </font>
# </div>

# %%
#TODO
high_duration=movies.sort_values('duration',ascending=False)
high_duration
# Out:
#      star_rating                              title content_rating      genre  \
# 476          7.8                             Hamlet          PG-13      Drama
# 157          8.2                 Gone with the Wind              G      Drama
# 78           8.4        Once Upon a Time in America              R      Crime
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# ..           ...                                ...            ...        ...
# 293          8.1                          Duck Soup         PASSED     Comedy
# 88           8.4                            The Kid      NOT RATED     Comedy
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED      Crime
# 338          8.0                Battleship Potemkin        UNRATED    History
# 389          8.0                             Freaks        UNRATED      Drama
#
#      duration                                        actors_list
# 476       242  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 157       238  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 78        229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 445       220  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...
# ..        ...                                                ...
# 293        68    [u'Groucho Marx', u'Harpo Marx', u'Chico Marx']
# 88         68  [u'Charles Chaplin', u'Edna Purviance', u'Jack...
# 258        67  [u'Werner Krauss', u'Conrad Veidt', u'Friedric...
# 338        66  [u'Aleksandr Antonov', u'Vladimir Barsky', u'G...
# 389        64  [u'Wallace Ford', u'Leila Hyams', u'Olga Bacla...
#
# [976 rows x 6 columns]

# %%
new_df=high_duration.iloc[:50]
new_df
# Out:
#      star_rating                                              title  \
# 476          7.8                                             Hamlet
# 157          8.2                                 Gone with the Wind
# 78           8.4                        Once Upon a Time in America
# 142          8.3                  Lagaan: Once Upon a Time in India
# 445          7.9                               The Ten Commandments
# 85           8.4                                 Lawrence of Arabia
# 204          8.1                                            Ben-Hur
# 17           8.7                                      Seven Samurai
# 767          7.6                    It's a Mad, Mad, Mad, Mad World
# 630          7.7                                          Malcolm X
# 7            8.9      The Lord of the Rings: The Return of the King
# 2            9.1                             The Godfather: Part II
# 335          8.0                                     Doctor Zhivago
# 385          8.0                                          Spartacus
# 8            8.9                                   Schindler's List
# 620          7.7                                            Titanic
# 424          7.9                                    The Right Stuff
# 220          8.1                                             Gandhi
# 671          7.7                                         Grindhouse
# 40           8.5                                     The Green Mile
# 89           8.4                                             Swades
# 316          8.0                                                JFK
# 318          8.0                                           Magnolia
# 184          8.2                                Fanny and Alexander
# 611          7.7                                         Short Cuts
# 132          8.3                              Judgment at Nuremberg
# 245          8.1                                       Barry Lyndon
# 109          8.3                                     Dil Chahta Hai
# 166          8.2                                    The Deer Hunter
# 339          8.0                                 Dances with Wolves
# 93           8.4                        Dilwale Dulhania Le Jayenge
# 361          8.0                                Fiddler on the Roof
# 143          8.2                            The Wolf of Wall Street
# 14           8.8              The Lord of the Rings: The Two Towers
# 456          7.9                          Blue Is the Warmest Color
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 534          7.8                                    The Longest Day
# 156          8.2                                             Casino
# 300          8.0                                           Dogville
# 82           8.4                                         Braveheart
# 1            9.2                                      The Godfather
# 941          7.4                                   A Bridge Too Far
# 26           8.6                       Once Upon a Time in the West
# 348          8.0                                 The Sound of Music
# 231          8.1                                      La Dolce Vita
# 159          8.2                        The Best Years of Our Lives
# 302          8.0                                             Patton
# 120          8.3                                   The Great Escape
# 842          7.5                                        Cloud Atlas
# 888          7.5                                        The Aviator
#
#     content_rating      genre  duration  \
# 476          PG-13      Drama       242
# 157              G      Drama       238
# 78               R      Crime       229
# 142             PG  Adventure       224
# 445       APPROVED  Adventure       220
# 85              PG  Adventure       216
# 204              G  Adventure       212
# 17         UNRATED      Drama       207
# 767       APPROVED     Action       205
# 630          PG-13  Biography       202
# 7            PG-13  Adventure       201
# 2                R      Crime       200
# 335          PG-13      Drama       197
# 385          PG-13     Action       197
# 8                R  Biography       195
# 620          PG-13      Drama       194
# 424              R  Adventure       193
# 220             PG  Biography       191
# 671              R     Action       191
# 40               R      Crime       189
# 89       NOT RATED      Drama       189
# 316              R      Drama       189
# 318              R      Drama       188
# 184              R      Drama       188
# 611              R     Comedy       187
# 132      NOT RATED      Drama       186
# 245             PG  Adventure       184
# 109      NOT RATED     Comedy       183
# 166              R      Drama       182
# 339          PG-13  Adventure       181
# 93       NOT RATED     Comedy       181
# 361              G      Drama       181
# 143              R  Biography       180
# 14           PG-13  Adventure       179
# 456          NC-17      Drama       179
# 10           PG-13  Adventure       178
# 534              G     Action       178
# 156              R  Biography       178
# 300              R      Crime       178
# 82               R     Action       177
# 1                R      Crime       175
# 941             PG      Drama       175
# 26           PG-13    Western       175
# 348              G  Biography       174
# 231      NOT RATED     Comedy       174
# 159         PASSED      Drama       172
# 302             GP  Biography       172
# 120        UNRATED  Adventure       172
# 842              R      Drama       172
# 888          PG-13  Biography       170
#
#                                            actors_list
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 78   [u'Robert De Niro', u'James Woods', u'Elizabet...
# 142  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 445  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...
# 85   [u"Peter O'Toole", u'Alec Guinness', u'Anthony...
# 204  [u'Charlton Heston', u'Jack Hawkins', u'Stephe...
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 767  [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...
# 630  [u'Denzel Washington', u'Angela Bassett', u'De...
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 335  [u'Omar Sharif', u'Julie Christie', u'Geraldin...
# 385  [u'Kirk Douglas', u'Laurence Olivier', u'Jean ...
# 8    [u'Liam Neeson', u'Ralph Fiennes', u'Ben Kings...
# 620  [u'Leonardo DiCaprio', u'Kate Winslet', u'Bill...
# 424     [u'Sam Shepard', u'Scott Glenn', u'Ed Harris']
# 220  [u'Ben Kingsley', u'John Gielgud', u'Candice B...
# 671  [u'Kurt Russell', u'Rose McGowan', u'Danny Tre...
# 40   [u'Tom Hanks', u'Michael Clarke Duncan', u'Dav...
# 89   [u'Shah Rukh Khan', u'Gayatri Joshi', u'Kishor...
# 316  [u'Kevin Costner', u'Gary Oldman', u'Jack Lemm...
# 318  [u'Tom Cruise', u'Jason Robards', u'Julianne M...
# 184  [u'Bertil Guve', u'Pernilla Allwin', u'Kristin...
# 611  [u'Andie MacDowell', u'Julianne Moore', u'Tim ...
# 132  [u'Spencer Tracy', u'Burt Lancaster', u'Richar...
# 245  [u"Ryan O'Neal", u'Marisa Berenson', u'Patrick...
# 109  [u'Aamir Khan', u'Saif Ali Khan', u'Akshaye Kh...
# 166  [u'Robert De Niro', u'Christopher Walken', u'J...
# 339  [u'Kevin Costner', u'Mary McDonnell', u'Graham...
# 93       [u'Shah Rukh Khan', u'Kajol', u'Amrish Puri']
# 361        [u'Topol', u'Norma Crane', u'Leonard Frey']
# 143  [u'Leonardo DiCaprio', u'Jonah Hill', u'Margot...
# 14   [u'Elijah Wood', u'Ian McKellen', u'Viggo Mort...
# 456  [u'L\xe9a Seydoux', u'Ad\xe8le Exarchopoulos',...
# 10   [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# 534  [u'John Wayne', u'Robert Ryan', u'Richard Burt...
# 156  [u'Robert De Niro', u'Sharon Stone', u'Joe Pes...
# 300  [u'Nicole Kidman', u'Paul Bettany', u'Lauren B...
# 82   [u'Mel Gibson', u'Sophie Marceau', u'Patrick M...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 941  [u'Sean Connery', u"Ryan O'Neal", u'Michael Ca...
# 26   [u'Henry Fonda', u'Charles Bronson', u'Claudia...
# 348  [u'Julie Andrews', u'Christopher Plummer', u'E...
# 231  [u'Marcello Mastroianni', u'Anita Ekberg', u'A...
# 159  [u'Fredric March', u'Dana Andrews', u'Myrna Loy']
# 302  [u'George C. Scott', u'Karl Malden', u'Stephen...
# 120  [u'Steve McQueen', u'James Garner', u'Richard ...
# 842      [u'Tom Hanks', u'Halle Berry', u'Hugh Grant']
# 888  [u'Leonardo DiCaprio', u'Cate Blanchett', u'Ka...

# %%
long_time=new_df.to_csv()

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
#          تابعی بنویسید که نام بازیگر را به عنوان آرگومان بگیرد و تعداد فیلم های برتر از این لیست را که بازی کرده محاسبه کند.
#         <br/>
#     </font>
# </div>

# %%
#TODO

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
#          میانگین امتیاز فیلم ها را براساس ژانر نمایش به دست آورید.
#         <br/>
#     </font>
# </div>

# %%
#TODO
movies.groupby('genre')['star_rating'].mean().sort_values(ascending=False)
# Out:
# genre
# Western      8.255556
# Film-Noir    8.033333
# History      8.000000
# Mystery      7.975000
# Adventure    7.940541
# Sci-Fi       7.920000
# Crime        7.916935
# Animation    7.914516
# Drama        7.902518
# Action       7.885926
# Biography    7.857895
# Family       7.850000
# Comedy       7.822436
# Horror       7.806897
# Fantasy      7.700000
# Thriller     7.680000
# Name: star_rating, dtype: float64

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
#        ستونی به این داده ها اضافه کنید که در صورت اینکه یک فیلم مدت نمایش آن 150 دقیقه و یا بیشتر بود مقدار صفر و در غیر اینصورت 1 در هر سطر این ستون قرار گیرد. دیتافریم حاصل را در یک فایل csv ذخیره کنید.
#         <br/>
#     </font>
# </div>

# %%
#TODO

movies['more_than_150']=movies['duration'].apply(lambda x: 1 if x>=150 else 0)
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# 3            PG-13     Action       152
# 4                R      Crime       154
# ..             ...        ...       ...
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list  more_than_150
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...              0
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']              1
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...              1
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...              1
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....              1
# ..                                                 ...            ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...              0
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...              0
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...              0
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...              0
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...              0
#
# [976 rows x 7 columns]

# %%
new_movies=movies.to_csv()

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
#         عنوان ستونها را به نحوی تغییر دهید که در ستون های دارای _(آندرلاین) فاصله قرار گیرد. به عنوان مثال star_rating به star rating تبدیل می شود.
#         <br/>
#     </font>
# </div>

# %%
#TODO
movies.columns = movies.columns.str.replace('_', ' ')
movies
# Out:
#      star rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# 3            PG-13     Action       152
# 4                R      Crime       154
# ..             ...        ...       ...
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors list  more than 150
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...              0
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']              1
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...              1
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...              1
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....              1
# ..                                                 ...            ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...              0
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...              0
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...              0
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...              0
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...              0
#
# [976 rows x 7 columns]

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
#         داده ها را براساس ژانر گروه بندی و مرتب کنید و از هر ژانر صرفا سه تای برتر را نمایش دهید
#         <br/>
#     </font>
# </div>

# %%
#TODO
movies.groupby('genre').apply(lambda x: x.sort_values('star rating',ascending=False).head(3))
# Out:
#                star rating                                              title  \
# genre
# Action    3            9.0                                    The Dark Knight
#           12           8.8     Star Wars: Episode V - The Empire Strikes Back
#           11           8.8                                          Inception
# Adventure 7            8.9      The Lord of the Rings: The Return of the King
#           14           8.8              The Lord of the Rings: The Two Towers
#           10           8.8  The Lord of the Rings: The Fellowship of the Ring
# Animation 30           8.6                                      Spirited Away
#           61           8.5                             Grave of the Fireflies
#           55           8.5                                      The Lion King
# Biography 8            8.9                                   Schindler's List
#           18           8.7                                         Goodfellas
#           31           8.6                                   The Intouchables
# Comedy    25           8.6                                  Life Is Beautiful
#           35           8.6                                       Modern Times
#           29           8.6                                        City Lights
# Crime     0            9.3                           The Shawshank Redemption
#           1            9.2                                      The Godfather
#           2            9.1                             The Godfather: Part II
# Drama     5            8.9                                       12 Angry Men
#           9            8.9                                         Fight Club
#           13           8.8                                       Forrest Gump
# Family    468          7.9                         E.T. the Extra-Terrestrial
#           497          7.8                Willy Wonka & the Chocolate Factory
# Fantasy   638          7.7                          The City of Lost Children
# Film-Noir 105          8.3                                      The Third Man
#           210          8.1                                              Laura
#           687          7.7                                         Spellbound
# History   338          8.0                                Battleship Potemkin
# Horror    39           8.6                                             Psycho
#           57           8.5                                              Alien
#           62           8.5                                        The Shining
# Mystery   38           8.6                                        Rear Window
#           46           8.5                                            Memento
#           76           8.4                                            Vertigo
# Sci-Fi    145          8.2                                       Blade Runner
#           321          8.0                                             Brazil
#           408          7.9                                            Gravity
# Thriller  350          8.0                                  Shadow of a Doubt
#           496          7.8                                             Misery
#           728          7.6                                 La piel que habito
# Western   6            8.9                     The Good, the Bad and the Ugly
#           26           8.6                       Once Upon a Time in the West
#           59           8.5                                   Django Unchained
#
#               content rating      genre  duration  \
# genre
# Action    3            PG-13     Action       152
#           12              PG     Action       124
#           11           PG-13     Action       148
# Adventure 7            PG-13  Adventure       201
#           14           PG-13  Adventure       179
#           10           PG-13  Adventure       178
# Animation 30              PG  Animation       125
#           61         UNRATED  Animation        89
#           55               G  Animation        89
# Biography 8                R  Biography       195
#           18               R  Biography       146
#           31               R  Biography       112
# Comedy    25           PG-13     Comedy       116
#           35               G     Comedy        87
#           29          PASSED     Comedy        87
# Crime     0                R      Crime       142
#           1                R      Crime       175
#           2                R      Crime       200
# Drama     5        NOT RATED      Drama        96
#           9                R      Drama       139
#           13           PG-13      Drama       142
# Family    468             PG     Family       115
#           497              G     Family       100
# Fantasy   638              R    Fantasy       112
# Film-Noir 105      NOT RATED  Film-Noir        93
#           210       APPROVED  Film-Noir        88
#           687        UNRATED  Film-Noir       111
# History   338        UNRATED    History        66
# Horror    39               R     Horror       109
#           57               R     Horror       117
#           62               R     Horror       146
# Mystery   38        APPROVED    Mystery       112
#           46               R    Mystery       113
#           76        APPROVED    Mystery       128
# Sci-Fi    145              R     Sci-Fi       117
#           321              R     Sci-Fi       132
#           408          PG-13     Sci-Fi        91
# Thriller  350       APPROVED   Thriller       108
#           496              R   Thriller       107
#           728              R   Thriller       120
# Western   6        NOT RATED    Western       161
#           26           PG-13    Western       175
#           59               R    Western       165
#
#                                                      actors list  \
# genre
# Action    3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
#           12   [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
#           11   [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...
# Adventure 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
#           14   [u'Elijah Wood', u'Ian McKellen', u'Viggo Mort...
#           10   [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# Animation 30   [u'Daveigh Chase', u'Suzanne Pleshette', u'Miy...
#           61   [u'Tsutomu Tatsumi', u'Ayano Shiraishi', u'Ake...
#           55   [u'Matthew Broderick', u'Jeremy Irons', u'Jame...
# Biography 8    [u'Liam Neeson', u'Ralph Fiennes', u'Ben Kings...
#           18    [u'Robert De Niro', u'Ray Liotta', u'Joe Pesci']
#           31   [u'Fran\xe7ois Cluzet', u'Omar Sy', u'Anne Le ...
# Comedy    25   [u'Roberto Benigni', u'Nicoletta Braschi', u'G...
#           35   [u'Charles Chaplin', u'Paulette Goddard', u'He...
#           29   [u'Charles Chaplin', u'Virginia Cherrill', u'F...
# Crime     0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
#           1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
#           2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# Drama     5    [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
#           9    [u'Brad Pitt', u'Edward Norton', u'Helena Bonh...
#           13     [u'Tom Hanks', u'Robin Wright', u'Gary Sinise']
# Family    468  [u'Henry Thomas', u'Drew Barrymore', u'Peter C...
#           497  [u'Gene Wilder', u'Jack Albertson', u'Peter Os...
# Fantasy   638  [u'Ron Perlman', u'Daniel Emilfork', u'Judith ...
# Film-Noir 105  [u'Orson Welles', u'Joseph Cotten', u'Alida Va...
#           210  [u'Gene Tierney', u'Dana Andrews', u'Clifton W...
#           687  [u'Ingrid Bergman', u'Gregory Peck', u'Michael...
# History   338  [u'Aleksandr Antonov', u'Vladimir Barsky', u'G...
# Horror    39   [u'Anthony Perkins', u'Janet Leigh', u'Vera Mi...
#           57   [u'Sigourney Weaver', u'Tom Skerritt', u'John ...
#           62   [u'Jack Nicholson', u'Shelley Duvall', u'Danny...
# Mystery   38   [u'James Stewart', u'Grace Kelly', u'Wendell C...
#           46   [u'Guy Pearce', u'Carrie-Anne Moss', u'Joe Pan...
#           76   [u'James Stewart', u'Kim Novak', u'Barbara Bel...
# Sci-Fi    145  [u'Harrison Ford', u'Rutger Hauer', u'Sean You...
#           321  [u'Jonathan Pryce', u'Kim Greist', u'Robert De...
#           408  [u'Sandra Bullock', u'George Clooney', u'Ed Ha...
# Thriller  350  [u'Teresa Wright', u'Joseph Cotten', u'Macdona...
#           496  [u'James Caan', u'Kathy Bates', u'Richard Farn...
#           728  [u'Antonio Banderas', u'Elena Anaya', u'Jan Co...
# Western   6    [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...
#           26   [u'Henry Fonda', u'Charles Bronson', u'Claudia...
#           59   [u'Jamie Foxx', u'Christoph Waltz', u'Leonardo...
#
#                more than 150
# genre
# Action    3                1
#           12               0
#           11               0
# Adventure 7                1
#           14               1
#           10               1
# Animation 30               0
#           61               0
#           55               0
# Biography 8                1
#           18               0
#           31               0
# Comedy    25               0
#           35               0
#           29               0
# Crime     0                0
#           1                1
#           2                1
# Drama     5                0
#           9                0
#           13               0
# Family    468              0
#           497              0
# Fantasy   638              0
# Film-Noir 105              0
#           210              0
#           687              0
# History   338              0
# Horror    39               0
#           57               0
#           62               0
# Mystery   38               0
#           46               0
#           76               0
# Sci-Fi    145              0
#           321              0
#           408              0
# Thriller  350              0
#           496              0
#           728              0
# Western   6                1
#           26               1
#           59               1

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
# 		<font color=red size=5>
#             سوال دوم:‌
#         </font>
#         تفاوت بین متد read_table و read_csv در ماژول pandas چیست؟
#         <br/>
#     </font>
# </div>

# %% [markdown]
#
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" color=green size=4>
#         هردو تقریبا یکی هستند و در هردو یک تابع فراخوانی می شود ولی  read_csv ،delimiter یک کاما است ولی در read_table  یک Tab
#  است.
#         <br/>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
# 		<font color=red size=5>
#             سوال سوم:‌
#         </font>
#         با استفاده از متد value_counts تعداد فیلمها در هر ریت محتوا را به دست آورید.
#         <br/>
#     </font>
# </div>

# %%
movies['content rating'].value_counts()
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# PASSED         7
# NC-17          7
# X              4
# GP             3
# TV-MA          1
# Name: content rating, dtype: int64

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
# 		<font color=red size=5>
#             سوال چهارم:‌
#         </font>
#        توضیح دهید crosstab در پانداس چه میکند و عملکرد آنرا بر روی کد زیر توضیح دهید؟
#         <br/>
#     </font>
# </div>

# %%
pd.crosstab(movies['genre'], movies['content rating'])
# Out:
# content rating  APPROVED   G  GP  NC-17  NOT RATED  PASSED  PG  PG-13    R  \
# genre
# Action                 3   1   1      0          4       1  11     44   67
# Adventure              3   2   0      0          5       1  21     23   17
# Animation              3  20   0      0          3       0  25      5    5
# Biography              1   2   1      0          1       0   6     29   36
# Comedy                 9   2   1      1         16       3  23     23   73
# Crime                  6   0   0      1          7       1   6      4   87
# Drama                 12   3   0      4         24       1  25     55  143
# Family                 0   1   0      0          0       0   1      0    0
# Fantasy                0   0   0      0          0       0   0      0    1
# Film-Noir              1   0   0      0          1       0   0      0    0
# History                0   0   0      0          0       0   0      0    0
# Horror                 2   0   0      1          1       0   1      2   16
# Mystery                4   1   0      0          1       0   1      2    6
# Sci-Fi                 1   0   0      0          0       0   0      1    3
# Thriller               1   0   0      0          0       0   1      0    3
# Western                1   0   0      0          2       0   2      1    3
#
# content rating  TV-MA  UNRATED  X
# genre
# Action              0        3  0
# Adventure           0        2  0
# Animation           0        1  0
# Biography           0        0  0
# Comedy              0        4  1
# Crime               0       11  1
# Drama               1        9  1
# Family              0        0  0
# Fantasy             0        0  0
# Film-Noir           0        1  0
# History             0        1  0
# Horror              0        5  1
# Mystery             0        1  0
# Sci-Fi              0        0  0
# Thriller            0        0  0
# Western             0        0  0

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
#    <font face="XB Zar" color=green size=4>
#         این تابع مقادیر ستون اولی که بهش میدهیم را در سطر ها و مقادیر ستون دوم را در ستونها قرار میدهد. و تعدادی که از هرکدام موجود است را نشان می دهد.
#         به عنوان مثال در اینجا تعداد فیلم هایی با ژانر اکشن که ratingاشان approved است 3 میباشد.
#         <br/>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
# 		<font color=red size=5>
#             سوال پنچم:‌
#         </font>
#          توضیح دهید متد corr در پانداس چه میکند و عملکرد آنرا بر روی کد زیر توضیح دهید؟
#         <br/>
#     </font>
# </div>

# %%
movies.corr()
# Out:
#                star rating  duration  more than 150
# star rating       1.000000  0.229410       0.223764
# duration          0.229410  1.000000       0.744606
# more than 150     0.223764  0.744606       1.000000

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
#    <font face="XB Zar" color=green size=4>
#         این متد رابطه جفت به جفت ستون ها را نشان میدهد رابطه هر ستون با خودش یک است یعنی بیشترین رابطه و وابستگی .
#        در این دیتاست با نگاه کردن به corr می فهمیم دو ستون more than 150  و duration بیشترین وابستگی ولی در عوض دو ستون  more than 150 و  star rating .کمترین رابطه یا وابستگی را دارند
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
# 		<font color=red size=5>
#             سوال ششم:‌
#         </font>
#         با استفاده از متد sample هفتاد و پنج درصد سطرها را در یک متغیر به نام sample_1 بریزید. درنهایت با استفاده از متد drop از دیتافریم اصلی این سطرها را حذف و دیتافریم جدید را در sample_2 بریزید
#         <br/>
#     </font>
# </div>

# %%
#TODO
sample_1=movies.sample(frac=0.75)
sample_1
# Out:
#      star rating                            title content rating      genre  \
# 342          8.0               Dead Poets Society             PG      Drama
# 101          8.3  Monty Python and the Holy Grail             PG  Adventure
# 34           8.6               American History X              R      Crime
# 692          7.7                             MASH              R     Comedy
# 709          7.6                  The Illusionist          PG-13      Drama
# ..           ...                              ...            ...        ...
# 312          8.0                        Star Trek          PG-13     Action
# 671          7.7                       Grindhouse              R     Action
# 743          7.6                    Kung Fu Panda             PG  Animation
# 438          7.9                     Lilya 4-Ever              R      Crime
# 682          7.7                        Philomena          PG-13  Biography
#
#      duration                                        actors list  \
# 342       128  [u'Robin Williams', u'Robert Sean Leonard', u'...
# 101        91  [u'Graham Chapman', u'John Cleese', u'Eric Idle']
# 34        119  [u'Edward Norton', u'Edward Furlong', u"Beverl...
# 692       116  [u'Donald Sutherland', u'Elliott Gould', u'Tom...
# 709       110  [u'Edward Norton', u'Jessica Biel', u'Paul Gia...
# ..        ...                                                ...
# 312       127  [u'Chris Pine', u'Zachary Quinto', u'Simon Pegg']
# 671       191  [u'Kurt Russell', u'Rose McGowan', u'Danny Tre...
# 743        92  [u'Jack Black', u'Ian McShane', u'Angelina Jol...
# 438       109  [u'Oksana Akinshina', u'Artyom Bogucharskiy', ...
# 682        98  [u'Judi Dench', u'Steve Coogan', u'Sophie Kenn...
#
#      more than 150
# 342              0
# 101              0
# 34               0
# 692              0
# 709              0
# ..             ...
# 312              0
# 671              1
# 743              0
# 438              0
# 682              0
#
# [732 rows x 7 columns]

# %%
sample_2=movies.drop(sample_1.index)
sample_2
# Out:
#      star rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 22           8.7                            It's a Wonderful Life
# ..           ...                                              ...
# 972          7.4                                   Blue Valentine
# 973          7.4                            The Cider House Rules
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
#
#     content rating      genre  duration  \
# 0                R      Crime       142
# 2                R      Crime       200
# 3            PG-13     Action       152
# 12              PG     Action       124
# 22        APPROVED      Drama       130
# ..             ...        ...       ...
# 972          NC-17      Drama       112
# 973          PG-13      Drama       126
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
#
#                                            actors list  more than 150
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...              0
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...              1
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...              1
# 12   [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...              0
# 22   [u'James Stewart', u'Donna Reed', u'Lionel Bar...              0
# ..                                                 ...            ...
# 972  [u'Ryan Gosling', u'Michelle Williams', u'John...              0
# 973  [u'Tobey Maguire', u'Charlize Theron', u'Micha...              0
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...              0
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...              0
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...              0
#
# [244 rows x 7 columns]

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
# 	<font face="XB Zar" size=4>
# 		<font color=red size=5>
#             سوال هفتم:‌
#         </font>
#          متد pivot_table چه عملکردی دارد؟
#         <br/>
#     </font>
# </div>

# %% [markdown]
# <div dir = "rtl" style="direction:rtl;line-height:300%;">
#    <font face="XB Zar" color=green size=4>
#     متد pivot برای reshape کردن دیتاست به کار می رود . زمانی از این متد استفاده میکنیم که میخواهیم نمایش بهتری از رابطه ستون ها با هم داشته باشیم.
#     این متد index , column , value دارد که با دادن هرکدام از ستون ها به آن ها خروجی یک دیتافریم می شود.
#         <br/>
#     </font>
# </div>
