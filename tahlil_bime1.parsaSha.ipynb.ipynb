# %%
import pandas as pd

# %%
bime = pd.read_csv('train.csv')
bime
# Out:
#        Customer Id  Age               Employment Type GraduateOrNot  \
# 0     3JUN0VW6F043   34  Private Sector/Self Employed           Yes
# 1     VLHY2ABIR4QL   28  Private Sector/Self Employed           Yes
# 2     6E3F7UNXYNFF   28  Private Sector/Self Employed           Yes
# 3     JJ8R0ZRYWR31   32             Government Sector           Yes
# 4     2WGFUEX6IEHM   34  Private Sector/Self Employed           Yes
# ...            ...  ...                           ...           ...
# 1585  W9JDK752JWHA   29  Private Sector/Self Employed           Yes
# 1586  2JEE5P5T9MT0   34  Private Sector/Self Employed           Yes
# 1587  797K83M5QWO2   34  Private Sector/Self Employed            No
# 1588  8V9QYC8TCCMF   33             Government Sector           Yes
# 1589  8VEME4MXPTBC   28  Private Sector/Self Employed           Yes
#
#       AnnualIncome  FamilyMembers  ChronicDiseases FrequentFlyer  \
# 0          1300000              6                0           Yes
# ...

# %%
###soal tedad satr v soton
bimss = (bime.shape)
print(bimss[0] ,bimss[1])
# Out:
# 1590 11

# %%
###motevaset daramad salaneh
bime['motevassat'] = bime['AnnualIncome']//bime['FamilyMembers']
bime
# Out:
#        Customer Id  Age               Employment Type GraduateOrNot  \
# 0     3JUN0VW6F043   34  Private Sector/Self Employed           Yes
# 1     VLHY2ABIR4QL   28  Private Sector/Self Employed           Yes
# 2     6E3F7UNXYNFF   28  Private Sector/Self Employed           Yes
# 3     JJ8R0ZRYWR31   32             Government Sector           Yes
# 4     2WGFUEX6IEHM   34  Private Sector/Self Employed           Yes
# ...            ...  ...                           ...           ...
# 1585  W9JDK752JWHA   29  Private Sector/Self Employed           Yes
# 1586  2JEE5P5T9MT0   34  Private Sector/Self Employed           Yes
# 1587  797K83M5QWO2   34  Private Sector/Self Employed            No
# 1588  8V9QYC8TCCMF   33             Government Sector           Yes
# 1589  8VEME4MXPTBC   28  Private Sector/Self Employed           Yes
#
#       AnnualIncome  FamilyMembers  ChronicDiseases FrequentFlyer  \
# 0          1300000              6                0           Yes
# ...

# %%
#moshtarian sabeghe safar khareji
bime.groupby('EverTravelledAbroad').agg('size')["Yes"]
# Out:
# 302

# %%
# tedad bajhsh khososi v omomi
tedad_khsosi = (bime['Employment Type']=='Private Sector/Self Employed').value_counts(True)
tedad_gheir_khsosi = (bime['Employment Type']=='Government Sector').value_counts(True)

# %%
#tedad afrad daray bimari zaminehi bimeh shodeh

# %%
tedad_zaminehi = (bime['ChronicDiseases']==1).value_counts()[True]
tedad_bimehi = (bime['TravelInsurance']=='Yes').value_counts()[True]
result = tedad_zaminehi/tedad_bimehi
result.round(2)
# Out:
# 0.8
