# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,confusion_matrix,classification_report

# %% [markdown]
# # question

# %% [markdown]
# ### State with reasons whether the following sentences are true or false?

# %% [markdown]
# 1- The sentence "SVMs are not suitable for large datasets" is false. SVMs can handle large datasets efficiently due to their ability to work with subsets of training data called support vectors.
#
# 2- The sentence "SVMs perform poorly in imbalanced datasets" is true. SVMs aim to find a decision boundary that maximizes the margin between classes. In imbalanced datasets where one class has significantly fewer samples than the other, SVMs may misclassify the minority class due to the emphasis on maximizing the overall margin.
#
# 3- The sentence "SVMs perform poorly when there is just too much noise in the data" is true. SVMs are sensitive to noisy data and outliers. As noise interferes with the separation of classes, SVMs may struggle to find an optimal decision boundary, leading to decreased performance.

# %% [markdown]
# # lsvt-voice-rehabilitation

# %%
xls = pd.ExcelFile('LSVT_voice_rehabilitation.xlsx')
data = pd.read_excel(xls, 'Data')
response = pd.read_excel(xls, 'Binary response')
subject = pd.read_excel(xls, 'Subject demographics')

# %%
data
# Out:
#      Jitter->F0_abs_dif  Jitter->F0_dif_percent  \
# 0              0.088112                0.041697
# 1              0.161798                0.057364
# 2              0.554508                0.642913
# 3              0.031089                0.027108
# 4              0.076177                0.039071
# ..                  ...                     ...
# 121            0.116214                0.070546
# 122            0.700258                0.334397
# 123            0.072635                0.050743
# 124            0.111362                0.054237
# 125            0.256953                0.132694
#
#      Jitter->F0_PQ5_classical_Schoentgen  Jitter->F0_PQ5_classical_Baken  \
# 0                               0.000480                   -3.723304e-06
# 1                               0.000677                    5.466365e-06
# 2                               0.007576                   -7.443871e-07
# 3                               0.000314                   -2.214722e-07
# 4                               0.000302                    2.732106e-05
# ..                                   ...                             ...
# 121                             0.000837                    2.765074e-06
# 122                             0.003959                    8.297261e-06
# 123                             0.000597                   -5.277518e-06
# 124                             0.000646                   -1.546671e-06
# 125                             0.001576                    2.252403e-06
#
#      Jitter->F0_PQ5_generalised_Schoentgen  Jitter->F0_abs0th_perturb  \
# 0                                 0.000422                   2.458381
# 1                                 0.000206                   2.592066
# 2                                 0.006488                  12.691326
# 3                                 0.000216                   0.754288
# 4                                 0.001102                   1.270034
# ..                                     ...                        ...
# 121                               0.000333                   1.890006
# 122                               0.001516                   4.557797
# 123                               0.000434                   6.984651
# 124                               0.000277                   1.935398
# 125                               0.000708                   2.339807
#
#      Jitter->F0_CV  Jitter->F0_TKEO_mean  Jitter->F0_TKEO_std  \
# 0     6.332164e-07             47.021079          1366.430390
# 1     7.228518e-07             93.557936          2582.922776
# 2     6.946246e-04             52.988422           466.682635
# 3     1.868647e-07             13.982754           417.217249
# 4     4.918186e-05             56.373996          1608.317410
# ..             ...                   ...                  ...
# 121   9.844257e-07             34.083311           896.672947
# 122   1.581899e-05            104.648435          1583.166169
# 123   4.993260e-07             21.859427           625.288493
# 124   4.398078e-07             47.870508          1367.843467
# 125   3.050831e-06             52.103851          1124.445571
#
#      Jitter->F0_TKEO_prc5  ...  det_TKEO_std4_1_coef  det_TKEO_std4_2_coef  \
# 0               -7.103323  ...              2.527583              7.088978
# 1              -23.284761  ...              2.841881              7.977363
# 2              -45.308680  ...              1.806103              5.078616
# 3               -1.207741  ...              1.999637              5.610448
# 4               -3.491990  ...              2.453087              6.902199
# ..                    ...  ...                   ...                   ...
# 121            -10.446397  ...              2.322612              6.527285
# 122            -97.281717  ...              2.545596              7.160142
# 123             -4.116001  ...              2.189909              6.141876
# 124             -9.373059  ...              2.539158              7.125849
# 125            -38.918940  ...              2.441592              6.853709
#
#      det_TKEO_std4_3_coef  det_TKEO_std4_4_coef  det_TKEO_std4_5_coef  \
# 0               19.753255             54.335046            145.528630
# 1               22.203504             60.993338            163.560972
# 2               14.135923             38.641654            103.466808
# 3               15.626164             42.943275            115.014975
# 4               19.117609             52.715873            141.113865
# ..                    ...                   ...                   ...
# 121             18.210931             50.085484            134.123291
# 122             20.081389             55.178858            147.584708
# 123             17.095325             46.893015            125.687344
# 124             19.849347             54.508453            146.094711
# 125             19.071984             52.318080            140.093685
#
#      det_TKEO_std4_6_coef  det_TKEO_std4_7_coef  det_TKEO_std4_8_coef  \
# 0              375.097397            921.296579           2137.079844
# 1              421.010306           1036.092589           2404.072562
# 2              264.654626            649.657090           1507.384591
# 3              296.320795            728.284936           1689.586636
# 4              363.511021            893.246151           2071.625622
# ..                    ...                   ...                   ...
# 121            345.396264            850.942761           1973.383824
# 122            379.897760            935.982559           2166.960428
# 123            323.728298            795.715774           1845.609006
# 124            376.377835            926.435019           2147.499571
# 125            360.725864            885.933217           2052.423390
#
#      det_TKEO_std4_9_coef  det_TKEO_std4_10_coef
# 0             4697.131077            9931.208257
# 1             5284.082128           11165.095662
# 2             3315.804236            6974.600636
# 3             3713.818933            7851.139360
# 4             4554.204815            9623.566242
# ..                    ...                    ...
# 121           4336.099395            9158.984652
# 122           4769.956102           10067.750435
# 123           4056.256338            8583.121863
# 124           4717.270683            9966.759379
# 125           4511.560376            9542.064446
#
# [126 rows x 310 columns]

# %%
response
# Out:
#      Binary class 1=acceptable, 2=unacceptable
# 0                                            1
# 1                                            2
# 2                                            2
# 3                                            1
# 4                                            2
# ..                                         ...
# 121                                          2
# 122                                          2
# 123                                          1
# 124                                          2
# 125                                          2
#
# [126 rows x 1 columns]

# %%
subject
# Out:
#      Subject_index  Age  Gender, 0->Male, 1->Female
# 0                1   68                           1
# 1                1   68                           1
# 2                1   68                           1
# 3                2   68                           0
# 4                2   68                           0
# ..             ...  ...                         ...
# 121             15   63                           0
# 122             15   63                           0
# 123             16   69                           0
# 124             16   69                           0
# 125             16   69                           0
#
# [126 rows x 3 columns]

# %%
df = pd.concat([data,subject,response],axis=1)

# %%
df
# Out:
#      Jitter->F0_abs_dif  Jitter->F0_dif_percent  \
# 0              0.088112                0.041697
# 1              0.161798                0.057364
# 2              0.554508                0.642913
# 3              0.031089                0.027108
# 4              0.076177                0.039071
# ..                  ...                     ...
# 121            0.116214                0.070546
# 122            0.700258                0.334397
# 123            0.072635                0.050743
# 124            0.111362                0.054237
# 125            0.256953                0.132694
#
#      Jitter->F0_PQ5_classical_Schoentgen  Jitter->F0_PQ5_classical_Baken  \
# 0                               0.000480                   -3.723304e-06
# 1                               0.000677                    5.466365e-06
# 2                               0.007576                   -7.443871e-07
# 3                               0.000314                   -2.214722e-07
# 4                               0.000302                    2.732106e-05
# ..                                   ...                             ...
# 121                             0.000837                    2.765074e-06
# 122                             0.003959                    8.297261e-06
# 123                             0.000597                   -5.277518e-06
# 124                             0.000646                   -1.546671e-06
# 125                             0.001576                    2.252403e-06
#
#      Jitter->F0_PQ5_generalised_Schoentgen  Jitter->F0_abs0th_perturb  \
# 0                                 0.000422                   2.458381
# 1                                 0.000206                   2.592066
# 2                                 0.006488                  12.691326
# 3                                 0.000216                   0.754288
# 4                                 0.001102                   1.270034
# ..                                     ...                        ...
# 121                               0.000333                   1.890006
# 122                               0.001516                   4.557797
# 123                               0.000434                   6.984651
# 124                               0.000277                   1.935398
# 125                               0.000708                   2.339807
#
#      Jitter->F0_CV  Jitter->F0_TKEO_mean  Jitter->F0_TKEO_std  \
# 0     6.332164e-07             47.021079          1366.430390
# 1     7.228518e-07             93.557936          2582.922776
# 2     6.946246e-04             52.988422           466.682635
# 3     1.868647e-07             13.982754           417.217249
# 4     4.918186e-05             56.373996          1608.317410
# ..             ...                   ...                  ...
# 121   9.844257e-07             34.083311           896.672947
# 122   1.581899e-05            104.648435          1583.166169
# 123   4.993260e-07             21.859427           625.288493
# 124   4.398078e-07             47.870508          1367.843467
# 125   3.050831e-06             52.103851          1124.445571
#
#      Jitter->F0_TKEO_prc5  ...  det_TKEO_std4_5_coef  det_TKEO_std4_6_coef  \
# 0               -7.103323  ...            145.528630            375.097397
# 1              -23.284761  ...            163.560972            421.010306
# 2              -45.308680  ...            103.466808            264.654626
# 3               -1.207741  ...            115.014975            296.320795
# 4               -3.491990  ...            141.113865            363.511021
# ..                    ...  ...                   ...                   ...
# 121            -10.446397  ...            134.123291            345.396264
# 122            -97.281717  ...            147.584708            379.897760
# 123             -4.116001  ...            125.687344            323.728298
# 124             -9.373059  ...            146.094711            376.377835
# 125            -38.918940  ...            140.093685            360.725864
#
#      det_TKEO_std4_7_coef  det_TKEO_std4_8_coef  det_TKEO_std4_9_coef  \
# 0              921.296579           2137.079844           4697.131077
# 1             1036.092589           2404.072562           5284.082128
# 2              649.657090           1507.384591           3315.804236
# 3              728.284936           1689.586636           3713.818933
# 4              893.246151           2071.625622           4554.204815
# ..                    ...                   ...                   ...
# 121            850.942761           1973.383824           4336.099395
# 122            935.982559           2166.960428           4769.956102
# 123            795.715774           1845.609006           4056.256338
# 124            926.435019           2147.499571           4717.270683
# 125            885.933217           2052.423390           4511.560376
#
#      det_TKEO_std4_10_coef  Subject_index  Age  Gender, 0->Male, 1->Female  \
# 0              9931.208257              1   68                           1
# 1             11165.095662              1   68                           1
# 2              6974.600636              1   68                           1
# 3              7851.139360              2   68                           0
# 4              9623.566242              2   68                           0
# ..                     ...            ...  ...                         ...
# 121            9158.984652             15   63                           0
# 122           10067.750435             15   63                           0
# 123            8583.121863             16   69                           0
# 124            9966.759379             16   69                           0
# 125            9542.064446             16   69                           0
#
#      Binary class 1=acceptable, 2=unacceptable
# 0                                            1
# 1                                            2
# 2                                            2
# 3                                            1
# 4                                            2
# ..                                         ...
# 121                                          2
# 122                                          2
# 123                                          1
# 124                                          2
# 125                                          2
#
# [126 rows x 314 columns]

# %%
df.describe()
# Out:
#        Jitter->F0_abs_dif  Jitter->F0_dif_percent  \
# count          126.000000              126.000000
# mean             0.225683                0.119056
# std              0.345839                0.180097
# min              0.020443                0.013830
# 25%              0.057713                0.028676
# 50%              0.103926                0.048597
# 75%              0.192672                0.126339
# max              2.069748                0.933265
#
#        Jitter->F0_PQ5_classical_Schoentgen  Jitter->F0_PQ5_classical_Baken  \
# count                           126.000000                    1.260000e+02
# mean                              0.001385                   -6.951801e-07
# std                               0.002124                    1.573954e-05
# min                               0.000159                   -5.832686e-05
# 25%                               0.000320                   -5.121154e-06
# 50%                               0.000521                   -2.050570e-06
# 75%                               0.001487                    1.938132e-06
# max                               0.010925                    9.082689e-05
#
#        Jitter->F0_PQ5_generalised_Schoentgen  Jitter->F0_abs0th_perturb  \
# count                             126.000000                 126.000000
# mean                                0.001061                   6.937604
# std                                 0.001836                  24.275232
# min                                 0.000060                   0.548917
# 25%                                 0.000248                   1.158230
# 50%                                 0.000389                   2.012467
# 75%                                 0.001029                   3.251788
# max                                 0.010443                 218.686963
#
#        Jitter->F0_CV  Jitter->F0_TKEO_mean  Jitter->F0_TKEO_std  \
# count   1.260000e+02            126.000000           126.000000
# mean    1.660453e-04             82.190214          1796.302230
# std     8.712998e-04            106.894449          1631.244809
# min     7.679846e-08             13.319091           269.922782
# 25%     4.132032e-07             29.760987           807.453611
# 50%     9.491368e-07             52.594076          1356.767272
# 75%     9.886929e-06             91.694761          2380.748968
# max     7.890252e-03            906.320483         12299.065627
#
#        Jitter->F0_TKEO_prc5  ...  det_TKEO_std4_5_coef  det_TKEO_std4_6_coef  \
# count            126.000000  ...            126.000000            126.000000
# mean             -39.411240  ...            143.774055            370.528329
# std               98.188655  ...             20.468616             52.836331
# min             -624.951034  ...            103.466808            264.654626
# 25%              -23.075601  ...            128.924436            331.900606
# 50%               -8.833890  ...            141.675948            366.706743
# 75%               -4.115575  ...            155.552562            400.947223
# max               -0.603839  ...            198.333548            510.827346
#
#        det_TKEO_std4_7_coef  det_TKEO_std4_8_coef  det_TKEO_std4_9_coef  \
# count            126.000000            126.000000            126.000000
# mean             912.494576           2116.358203           4649.660947
# std              129.246368            296.400010            653.497584
# min              649.657090           1507.384591           3216.625092
# 25%              818.097730           1888.120153           4148.651943
# 50%              902.870861           2096.309958           4597.088099
# 75%              988.909310           2292.902649           5037.683060
# max             1257.014110           2916.248441           6406.074011
#
#        det_TKEO_std4_10_coef  Subject_index         Age  \
# count             126.000000     126.000000  126.000000
# mean             9813.389954       8.357143   61.928571
# std              1365.084335       4.927416    6.252268
# min              6700.842161       1.000000   51.000000
# 25%              8760.159506       4.000000   58.000000
# 50%              9741.107531       7.500000   63.500000
# 75%             10633.458586      13.000000   67.000000
# max             13537.402516      16.000000   69.000000
#
#        Gender, 0->Male, 1->Female  Binary class 1=acceptable, 2=unacceptable
# count                  126.000000                                 126.000000
# mean                     0.428571                                   1.666667
# std                      0.496847                                   0.473286
# min                      0.000000                                   1.000000
# 25%                      0.000000                                   1.000000
# 50%                      0.000000                                   2.000000
# 75%                      1.000000                                   2.000000
# max                      1.000000                                   2.000000
#
# [8 rows x 314 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Columns: 314 entries, Jitter->F0_abs_dif to Binary class 1=acceptable, 2=unacceptable
# dtypes: float64(309), int64(5)
# memory usage: 309.2 KB

# %% [markdown]
# ## Model

# %%
x_train,x_test,y_train,y_test = train_test_split(pd.concat([data,subject],axis=1),response,random_state=42)

# %%
x_train
# Out:
#      Jitter->F0_abs_dif  Jitter->F0_dif_percent  \
# 47             0.054323                0.017857
# 109            0.071532                0.035777
# 123            0.072635                0.050743
# 15             0.037592                0.025793
# 96             0.075121                0.042746
# ..                  ...                     ...
# 106            0.053964                0.024475
# 14             0.545266                0.215351
# 92             0.151367                0.095865
# 51             0.078691                0.021119
# 102            0.045881                0.032488
#
#      Jitter->F0_PQ5_classical_Schoentgen  Jitter->F0_PQ5_classical_Baken  \
# 47                              0.000203                   -3.843455e-06
# 109                             0.000382                   -1.487704e-05
# 123                             0.000597                   -5.277518e-06
# 15                              0.000306                    7.725535e-07
# 96                              0.000507                    8.374407e-07
# ..                                   ...                             ...
# 106                             0.000285                   -5.018743e-06
# 14                              0.002537                   -5.156799e-06
# 92                              0.001087                   -2.453946e-05
# 51                              0.000248                   -3.114055e-06
# 102                             0.000364                   -3.842865e-06
#
#      Jitter->F0_PQ5_generalised_Schoentgen  Jitter->F0_abs0th_perturb  \
# 47                                0.000240                   4.612988
# 109                               0.000611                   2.124373
# 123                               0.000434                   6.984651
# 15                                0.000108                   0.968243
# 96                                0.000227                   1.776438
# ..                                     ...                        ...
# 106                               0.000132                   2.015948
# 14                                0.001999                  16.726819
# 92                                0.001299                   1.198491
# 51                                0.000095                   1.806555
# 102                               0.000446                   0.819830
#
#      Jitter->F0_CV  Jitter->F0_TKEO_mean  Jitter->F0_TKEO_std  \
# 47    1.781817e-07             91.697524          2753.299161
# 109   2.974657e-06             38.980439          1086.227101
# 123   4.993260e-07             21.859427           625.288493
# 15    1.300052e-07             21.916628           664.710687
# 96    3.018278e-07             34.245446          1001.879061
# ..             ...                   ...                  ...
# 106   2.107112e-07             52.199730          1556.504881
# 14    1.956102e-05             73.152923           640.669570
# 92    5.333326e-06             29.120045           661.924062
# 51    1.099312e-07            143.972136          4342.907854
# 102   9.086350e-07             20.947815           625.518833
#
#      Jitter->F0_TKEO_prc5  ...  det_TKEO_std4_4_coef  det_TKEO_std4_5_coef  \
# 47              -7.130365  ...             61.931458            165.908079
# 109             -3.896339  ...             52.308884            140.229582
# 123             -4.116001  ...             46.893015            125.687344
# 15              -1.765231  ...             47.249466            126.589594
# 96              -4.836478  ...             51.346563            137.602442
# ..                    ...  ...                   ...                   ...
# 106             -4.279332  ...             55.986395            150.026007
# 14            -121.354402  ...             38.394547            106.478649
# 92             -16.034130  ...             47.720302            128.033687
# 51              -9.725394  ...             67.004863            179.541255
# 102             -1.718161  ...             46.686508            125.098729
#
#      det_TKEO_std4_6_coef  det_TKEO_std4_7_coef  det_TKEO_std4_8_coef  \
# 47             427.390937           1051.039031           2438.050611
# 109            361.486146            885.130393           2050.902403
# 123            323.728298            795.715774           1845.609006
# 15             326.072560            801.486390           1859.154995
# 96             354.293261            872.609610           2023.981089
# ..                    ...                   ...                   ...
# 106            386.456106            951.385565           2207.212963
# 14             279.072641            725.208967           1723.983681
# 92             330.022568            806.834995           1871.996734
# 51             462.526986           1138.003463           2638.819661
# 102            322.128771            790.865809           1834.387918
#
#      det_TKEO_std4_9_coef  det_TKEO_std4_10_coef  Subject_index  Age  \
# 47            5359.311281           11310.212172              2   68
# 109           4514.808902            9549.912566             11   62
# 123           4056.256338            8583.121863             16   69
# 15            4088.830256            8638.195110              6   58
# 96            4449.398057            9393.778399              5   62
# ..                    ...                    ...            ...  ...
# 106           4854.184043           10249.319805              8   65
# 14            4049.117874            8615.614385              5   62
# 92            4119.765350            8718.331650              3   67
# 51            5800.546445           12256.176332              4   64
# 102           4034.260040            8532.260430              7   51
#
#      Gender, 0->Male, 1->Female
# 47                            0
# 109                           1
# 123                           0
# 15                            0
# 96                            1
# ..                          ...
# 106                           1
# 14                            1
# 92                            0
# 51                            1
# 102                           0
#
# [94 rows x 313 columns]

# %%
y_train
# Out:
#      Binary class 1=acceptable, 2=unacceptable
# 47                                           2
# 109                                          2
# 123                                          1
# 15                                           1
# 96                                           1
# ..                                         ...
# 106                                          2
# 14                                           2
# 92                                           2
# 51                                           1
# 102                                          1
#
# [94 rows x 1 columns]

# %% [markdown]
# ### svm_linear

# %%
svm_linear = Pipeline([('scaler', StandardScaler()), 
                       ('lin', SVC(C=1,kernel='linear',random_state=42))
                      ])
svm_linear.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('lin', SVC(C=1, kernel='linear', random_state=42))])

# %%
cross_val_score(svm_linear, x_train, y_train, cv=5, scoring="f1")
# Out:
# array([0.61538462, 0.76923077, 0.66666667, 0.70588235, 0.6       ])

# %%
y_pred_l = svm_linear.predict(x_test)

# %%
print(f1_score(y_test, y_pred_l))
print(precision_score(y_test, y_pred_l))
print(recall_score(y_test, y_pred_l))
# Out:
# 0.72
# 0.5625
# 1.0

# %%
print(classification_report(y_test, y_pred_l))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.56      1.00      0.72         9
#            2       1.00      0.70      0.82        23
#
#     accuracy                           0.78        32
#    macro avg       0.78      0.85      0.77        32
# weighted avg       0.88      0.78      0.79        32

# %% [markdown]
# ### svm_polynomial

# %%
svm_poly = Pipeline([('scaler', StandardScaler()), 
                   ('poly', SVC(kernel='poly', random_state=42, degree=3, coef0=1))
                      ])

svm_poly.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('poly', SVC(coef0=1, kernel='poly', random_state=42))])

# %%
y_pred_p = svm_poly.predict(x_test)
print(f1_score(y_test, y_pred_p))
print(precision_score(y_test, y_pred_p))
print(recall_score(y_test, y_pred_p))
# Out:
# 0.761904761904762
# 0.6666666666666666
# 0.8888888888888888

# %%
print(classification_report(y_test, y_pred_p))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.67      0.89      0.76         9
#            2       0.95      0.83      0.88        23
#
#     accuracy                           0.84        32
#    macro avg       0.81      0.86      0.82        32
# weighted avg       0.87      0.84      0.85        32

# %% [markdown]
# ### svm_rbf

# %%
svm_rbf = Pipeline([('scaler', StandardScaler()), 
                    ('poly', SVC(kernel='rbf', random_state=42, gamma='auto'))
                      ])
svm_rbf.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('poly', SVC(gamma='auto', random_state=42))])

# %%
y_pred_r = svm_rbf.predict(x_test)
print(f1_score(y_test, y_pred_r))
print(precision_score(y_test, y_pred_r))
print(recall_score(y_test, y_pred_r))
# Out:
# 0.8750000000000001
# 1.0
# 0.7777777777777778

# %%
print(classification_report(y_test, y_pred_r))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      0.78      0.88         9
#            2       0.92      1.00      0.96        23
#
#     accuracy                           0.94        32
#    macro avg       0.96      0.89      0.92        32
# weighted avg       0.94      0.94      0.93        32

# %% [markdown]
# ### svm_sigmoid

# %%
svm_sig = Pipeline([('scaler', StandardScaler()), 
                    ('poly', SVC(kernel='sigmoid', random_state=42, gamma='auto', coef0=0.1))
                      ])
svm_sig.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('poly',
#                  SVC(coef0=0.1, gamma='auto', kernel='sigmoid',
#                      random_state=42))])

# %%
y_pred_s = svm_sig.predict(x_test)
print(f1_score(y_test, y_pred_s))
print(precision_score(y_test, y_pred_s))
print(recall_score(y_test, y_pred_s))
# Out:
# 0.8421052631578948
# 0.8
# 0.8888888888888888

# %%
print(classification_report(y_test, y_pred_s))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.80      0.89      0.84         9
#            2       0.95      0.91      0.93        23
#
#     accuracy                           0.91        32
#    macro avg       0.88      0.90      0.89        32
# weighted avg       0.91      0.91      0.91        32

# %% [markdown]
# ## Fine Tune

# %%
best_p_pipeline = Pipeline([
                    ('scalar',StandardScaler()),
                    ('svc',SVC())
                ])

# %%
parameters = {'svc__C': [0.1,1,4],
          'svc__coef0':[0,1,2],
          'svc__degree':[2,3,4],
          'svc__gamma':['auto','scale',0.01],
          'svc__kernel':['poly','rbf','sigmoid']}
grids = GridSearchCV(best_p_pipeline, parameters, cv=3, scoring='f1_macro')

# %%
grids.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('scalar', StandardScaler()),
#                                        ('svc', SVC())]),
#              param_grid={'svc__C': [0.1, 1, 4], 'svc__coef0': [0, 1, 2],
#                          'svc__degree': [2, 3, 4],
#                          'svc__gamma': ['auto', 'scale', 0.01],
#                          'svc__kernel': ['poly', 'rbf', 'sigmoid']},
#              scoring='f1_macro')

# %%
new_pred = grids.predict(x_test)

# %%
print(f1_score(y_test, new_pred))
print(precision_score(y_test, new_pred))
print(recall_score(y_test, new_pred))
# Out:
# 0.72
# 0.5625
# 1.0

# %%
print(classification_report(y_test, new_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.56      1.00      0.72         9
#            2       1.00      0.70      0.82        23
#
#     accuracy                           0.78        32
#    macro avg       0.78      0.85      0.77        32
# weighted avg       0.88      0.78      0.79        32

# %%
grids.best_params_
# Out:
# {'svc__C': 4,
#  'svc__coef0': 0,
#  'svc__degree': 2,
#  'svc__gamma': 'auto',
#  'svc__kernel': 'sigmoid'}

# %%
poly_svm = GridSearchCV(poly_FT, param_grid=poly_hyper, cv=3, scoring='f1_micro')
poly_svm.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('poly',
#                                         SVC(kernel='poly', random_state=42))]),
#              param_grid={'poly__coef0': range(2, 10),
#                          'poly__degree': range(2, 10)},
#              scoring='f1_micro')

# %%
poly_p = poly_svm.predict(x_test)

# %%
sig_FT = Pipeline([('scaler', StandardScaler()), 
                   ('poly', SVC(kernel='sigmoid', random_state=42))
                      ])
sig_hyper = {'poly__gamma': range(2,10,1) , 'poly__coef0': range(2,10,1)}

# %%
sig_svm = GridSearchCV(sig_FT, param_grid=sig_hyper, cv=3, scoring='f1_micro')
sig_svm.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('poly',
#                                         SVC(kernel='sigmoid',
#                                             random_state=42))]),
#              param_grid={'poly__coef0': range(2, 10),
#                          'poly__gamma': range(2, 10)},
#              scoring='f1_micro')

# %%
sig_p = sig_svm.predict(x_test)

# %% [markdown]
# in this set of data, after fine tuning, sigmoid has better function and f1_score
