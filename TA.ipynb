# %%
import pandas as pd

# %%
df = pd.read_sas('BMX_J.XPT')

# %%
df
# Out:
#           SEQN  BMDSTATS  BMXWT  BMIWT  BMXRECUM  BMIRECUM  BMXHEAD  BMIHEAD  \
# 0      93703.0       1.0   13.7    3.0      89.6       NaN      NaN      NaN
# 1      93704.0       1.0   13.9    NaN      95.0       NaN      NaN      NaN
# 2      93705.0       1.0   79.5    NaN       NaN       NaN      NaN      NaN
# 3      93706.0       1.0   66.3    NaN       NaN       NaN      NaN      NaN
# 4      93707.0       1.0   45.4    NaN       NaN       NaN      NaN      NaN
# ...        ...       ...    ...    ...       ...       ...      ...      ...
# 8699  102952.0       1.0   49.0    NaN       NaN       NaN      NaN      NaN
# 8700  102953.0       1.0   97.4    NaN       NaN       NaN      NaN      NaN
# 8701  102954.0       1.0   69.1    NaN       NaN       NaN      NaN      NaN
# 8702  102955.0       1.0  111.9    NaN       NaN       NaN      NaN      NaN
# 8703  102956.0       1.0  111.5    NaN       NaN       NaN      NaN      NaN
#
# ...

# %%
df.isnull().any()
# Out:
# SEQN        False
# BMDSTATS    False
# BMXWT        True
# BMIWT        True
# BMXRECUM     True
# BMIRECUM     True
# BMXHEAD      True
# BMIHEAD      True
# BMXHT        True
# BMIHT        True
# BMXBMI       True
# BMXLEG       True
# BMILEG       True
# BMXARML      True
# BMIARML      True
# BMXARMC      True
# BMIARMC      True
# BMXWAIST     True
# BMIWAIST     True
# BMXHIP       True
# BMIHIP       True
# dtype: bool

# %%
df.columns.nunique()
# Out:
# 21

# %%
pip install -U scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 2.2 MB/s eta 0:00:00m eta 0:00:010:00:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 2.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 KB 3.5 MB/s eta 0:00:000:00:010:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
null_percent = df.isnull().mean()

# %%
null_percent
# Out:
# SEQN        0.000000
# BMDSTATS    0.000000
# BMXWT       0.014246
# BMIWT       0.952206
# BMXRECUM    0.897289
# BMIRECUM    0.997243
# BMXHEAD     0.977711
# BMIHEAD     1.000000
# BMXHT       0.079044
# BMIHT       0.988626
# BMXBMI      0.080308
# BMXLEG      0.229894
# BMILEG      0.961627
# BMXARML     0.060547
# BMIARML     0.960133
# BMXARMC     0.061006
# BMIARMC     0.959789
# BMXWAIST    0.126723
# BMIWAIST    0.949793
# BMXHIP      0.306181
# BMIHIP      0.968980
# dtype: float64

# %%
from sklearn.cluster import KMeans

# %%
from seaborn import sns
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 from seaborn import sns
#
# ImportError: cannot import name 'sns' from 'seaborn' (/home/ubuntu/Machine Learning Bootcamp/ML Basic/ML_Basic_venv/lib/python3.10/site-packages/seaborn/__init__.py)

# %%
intended_cols = [col for col in df.columns if col[2]!='I']

# %%
df_rev = df[intended_cols]

# %%
find_row_null = df_rev.isna().sum(axis = 1)

# %%
sns.histplot(find_row_null)
# Out:
# <bound method hist_series of 0       3
# 1       3
# 2       2
# 3       2
# 4       2
#        ..
# 8699    2
# 8700    2
# 8701    2
# 8702    2
# 8703    2
# Length: 8704, dtype: int64>

# %%
df_last = df_rev.drop(['SEQN'], axiz = 1)
# Out:
#           SEQN  BMDSTATS  BMXWT  BMXRECUM  BMXHEAD  BMXHT  BMXBMI  BMXLEG  \
# 0      93703.0       1.0   13.7      89.6      NaN   88.6    17.5     NaN
# 1      93704.0       1.0   13.9      95.0      NaN   94.2    15.7     NaN
# 2      93705.0       1.0   79.5       NaN      NaN  158.3    31.7    37.0
# 3      93706.0       1.0   66.3       NaN      NaN  175.7    21.5    46.6
# 4      93707.0       1.0   45.4       NaN      NaN  158.4    18.1    38.1
# ...        ...       ...    ...       ...      ...    ...     ...     ...
# 8699  102952.0       1.0   49.0       NaN      NaN  156.5    20.0    34.4
# 8700  102953.0       1.0   97.4       NaN      NaN  164.9    35.8    38.2
# 8701  102954.0       1.0   69.1       NaN      NaN  162.6    26.1    39.2
# 8702  102955.0       1.0  111.9       NaN      NaN  156.6    45.6    39.2
# 8703  102956.0       1.0  111.5       NaN      NaN  175.8    36.1    42.5
#
#       BMXARML  BMXARMC  BMXWAIST  BMXHIP
# ...

# %%
df_last = df_last.drop(['BMXRECUM', ''], axiz = 1)

# %%
from sklearn.impute import SimpleImputer
import numpy as np


# To calculate mean use imputer class
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer = imputer.fit(X)

X_rev = imputer.transform(intended_cols)
print(X_rev)
